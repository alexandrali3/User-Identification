# %%
# %matplotlib inline

# %%
import sys
import numpy as np
import pandas as pd
import re as re
import matplotlib.pyplot as plt
import xgboost as xgb

# %%
train_uid = pd.read_table('../data/train/uid_train.txt', header = None, names = ['uid', 'label'])

# %%
print(train_uid.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 2 columns):
# uid      4999 non-null object
# label    4999 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 78.2+ KB
# None

# %%
train_voice = pd.read_table('../data/train/voice_train.txt', header = None, names = ['uid', 'opp_num', 'opp_head', 'opp_len', 'start_time', 'end_time', 'call_type', 'in_out'], dtype = {'opp_num':str})

# %%
print(train_voice.head())
# Out:
#      uid                           opp_num opp_head  opp_len  start_time  \
# 0  u0113  38D54642A237A11BB18455FC1E505292      132       11    26115956
# 1  u0113  38D54642A237A11BB18455FC1E505292      132       11    26115623
# 2  u0113  38D54642A237A11BB18455FC1E505292      132       11    26174233
# 3  u0113  38D54642A237A11BB18455FC1E505292      132       11    26070423
# 4  u3340  010A66F2AD42C48C44897A3DEC96A2A1      139       11    26201745
#
#    end_time  call_type  in_out
# 0  26120033          1       1
# 1  26115707          1       1
# 2  26174321          1       1
# 3  26070512          1       0
# 4  26201825          1       1

# %%
train_sms = pd.read_table('../data/train/sms_train.txt', header = None, names = ['uid', 'opp_num', 'opp_head', 'opp_len', 'start_time', 'in_out'], dtype = {'opp_num':str})

# %%
print(train_sms.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302976 entries, 0 to 302975
# Data columns (total 6 columns):
# uid           302976 non-null object
# opp_num       302976 non-null object
# opp_head      302976 non-null int64
# opp_len       302976 non-null int64
# start_time    302976 non-null int64
# in_out        302976 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 13.9+ MB
# None

# %%
train_wa = pd.read_table('../data/train/wa_train.txt', header = None, names = ['uid', 'wa_name', 'visit_cnt', 'visit_dura', 'up_flow', 'down_flow', 'wa_type', 'date'])

# %%
print(train_wa.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4808343 entries, 0 to 4808342
# Data columns (total 8 columns):
# uid           object
# wa_name       object
# visit_cnt     float64
# visit_dura    float64
# up_flow       float64
# down_flow     float64
# wa_type       float64
# date          float64
# dtypes: float64(6), object(2)
# memory usage: 293.5+ MB
# None

# %%
train_wa
# Out:
#            uid    wa_name  visit_cnt  visit_dura    up_flow  down_flow  \
# 0        u0001      155导航        5.0       207.0      313.0      457.0
# 1        u0001      155导航        7.0       396.0      547.0      659.0
# 2        u0001      155导航       10.0      3212.0      781.0      941.0
# 3        u0001      155导航       14.0       723.0     1094.0     1318.0
# 4        u0001      155导航       18.0       990.0     1406.0     1694.0
# 5        u0001      360借条        2.0       105.0      112.0      272.0
# 6        u0001      360借条        4.0      7428.0     3680.0     1076.0
# 7        u0001      360借条       10.0     11419.0    10535.0     3434.0
# 8        u0001      360借条       14.0     10051.0    13635.0     4318.0
# 9        u0001      360借条       22.0     17542.0    29674.0     8774.0
# 10       u0001      360借条       24.0     16316.0    19319.0     6324.0
# 11       u0001   360安全中心网        3.0      2317.0      558.0     1250.0
# 12       u0001   360安全中心网        4.0      6996.0     8308.0    21388.0
# 4808340  u4999       高德导航        6.0      7965.0     3250.0     3651.0
# 4808341  u4999       高德导航       10.0     11177.0     6718.0     9657.0
# 4808342  u4999       高德导航       19.0     15676.0     9680.0    12198.0
#
#          wa_type  date
# 0            0.0    14
# 1            0.0     4
# 2            0.0    12
# 3            0.0    10
# 4            0.0    11
# 5            1.0    12
# 6            1.0     9
# 7            1.0     1
# 8            1.0    11
# 9            1.0     4
# 10           1.0    10
# 11           0.0    14
# 12           0.0    31
# 13           0.0    12
# 14           0.0     9
# 15           0.0     1
# 16           0.0    11
# 17           0.0    10
# 18           0.0     4
# 19           0.0    14
# 20           0.0    12
# 21           0.0    10
# 22           0.0     9
# 23           0.0    30
# 24           0.0    11
# 25           0.0    31
# 26           0.0     9
# 27           0.0     9
# 28           0.0    11
# 29           0.0    10
# ...          ...   ...
# 4808313      0.0    40
# 4808314      0.0    36
# 4808315      0.0    42
# 4808316      1.0    45
# 4808317      1.0    35
# 4808318      1.0    32
# 4808319      0.0    43
# 4808320      1.0    36
# 4808321      1.0    44
# 4808322      0.0    36
# 4808323      1.0    41
# 4808324      0.0    42
# 4808325      0.0    45
# 4808326      0.0    41
# 4808327      0.0    44
# 4808328      0.0    40
# 4808329      0.0    43
# 4808330      0.0    45
# 4808331      0.0    32
# 4808332      0.0    45
# 4808333      0.0    45
# 4808334      0.0    40
# 4808335      0.0    44
# 4808336      0.0    43
# 4808337      0.0    34
# 4808338      0.0    41
# 4808339      0.0    42
# 4808340      0.0    32
# 4808341      0.0    45
# 4808342      0.0    35
#
# [4807542 rows x 8 columns]

# %%
train_wa_df.loc[:,'date'] = train_wa_df.loc[:,'date'].astype(int)

# %%
print(train_wa_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4807542 entries, 0 to 4808342
# Data columns (total 8 columns):
# uid           object
# wa_name       object
# visit_cnt     float64
# visit_dura    float64
# up_flow       float64
# down_flow     float64
# wa_type       float64
# date          int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 330.1+ MB
# None

# %%
train_wa_df.loc[:,'visit_cnt'] = train_wa_df.loc[:,'visit_cnt'].astype(int)

# %%
print(train_wa_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4807542 entries, 0 to 4808342
# Data columns (total 8 columns):
# uid           object
# wa_name       object
# visit_cnt     int64
# visit_dura    float64
# up_flow       float64
# down_flow     float64
# wa_type       float64
# date          int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 330.1+ MB
# None

# %%
train_wa_df.loc[:,['up_flow', 'down_flow']] = train_wa_df.loc[:,['up_flow','down_flow']].astype(int)

# %%
print(train_wa_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4807542 entries, 0 to 4808342
# Data columns (total 8 columns):
# uid           object
# wa_name       object
# visit_cnt     int64
# visit_dura    float64
# up_flow       int64
# down_flow     int64
# wa_type       float64
# date          int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 330.1+ MB
# None

# %%
train_wa_df.loc[:,['visit_dura', 'wa_type']] = train_wa_df.loc[:,['visit_dura', 'wa_type']].astype(int)

# %%
print(train_wa_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4807542 entries, 0 to 4808342
# Data columns (total 8 columns):
# uid           object
# wa_name       object
# visit_cnt     int64
# visit_dura    int64
# up_flow       int64
# down_flow     int64
# wa_type       int64
# date          int64
# dtypes: int64(6), object(2)
# memory usage: 330.1+ MB
# None

# %%
train_wa_df.loc[:,'wa_name'] = train_wa_df.loc[:,'wa_name'].astype(str)

# %%
print(train_wa_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4807542 entries, 0 to 4808342
# Data columns (total 8 columns):
# uid           object
# wa_name       object
# visit_cnt     int64
# visit_dura    int64
# up_flow       int64
# down_flow     int64
# wa_type       int64
# date          int64
# dtypes: int64(6), object(2)
# memory usage: 330.1+ MB
# None

# %%
print(train_wa_df.head(10))
# Out:
#      uid wa_name  visit_cnt  visit_dura  up_flow  down_flow  wa_type  date
# 0  u0001   155导航          5         207      313        457        0    14
# 1  u0001   155导航          7         396      547        659        0     4
# 2  u0001   155导航         10        3212      781        941        0    12
# 3  u0001   155导航         14         723     1094       1318        0    10
# 4  u0001   155导航         18         990     1406       1694        0    11
# 5  u0001   360借条          2         105      112        272        1    12
# 6  u0001   360借条          4        7428     3680       1076        1     9
# 7  u0001   360借条         10       11419    10535       3434        1     1
# 8  u0001   360借条         14       10051    13635       4318        1    11
# 9  u0001   360借条         22       17542    29674       8774        1     4

# %%
train_wa_df.to_csv('../data/train_wa_df.csv', index=False)

# %%
train_voice_df = train_voice

# %%
train_voice_df.loc[:,'in_out'] = train_voice_df.loc[:,'in_out'].astype(int)

# %%
print(train_voice_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1150778 entries, 0 to 1150777
# Data columns (total 8 columns):
# uid           1150778 non-null object
# opp_num       1150778 non-null object
# opp_head      1150778 non-null object
# opp_len       1150778 non-null int64
# start_time    1150778 non-null int64
# end_time      1150778 non-null int64
# call_type     1150778 non-null int64
# in_out        1150778 non-null int64
# dtypes: int64(5), object(3)
# memory usage: 70.2+ MB
# None

# %%
train_voice_df.to_csv('../data/train_voice_df.csv', index=False)

# %%
print(train_sms.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302976 entries, 0 to 302975
# Data columns (total 6 columns):
# uid           302976 non-null object
# opp_num       302976 non-null object
# opp_head      302976 non-null int64
# opp_len       302976 non-null int64
# start_time    302976 non-null int64
# in_out        302976 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 13.9+ MB
# None

# %%
train_sms_df = train_sms

# %%
train_sms_df.to_csv('../data/train/train_sms_df.csv', index=False)

# %%
train_voice_df = pd.read_csv('../data/train/train_voice_df.csv', header = 0, dtype = {'opp_num':str})
train_sms_df = pd.read_csv('../data/train/train_sms_df.csv', header = 0, dtype = {'opp_num':str})
train_wa_df = pd.read_csv('../data/train/train_wa_df.csv', header = 0)

# %%
def do(dataset):
    ans = dataset
    for index, row in dataset.iterrows():
        tmp = row['uid']
        ans.loc[index]['uid'] = tmp[1:]
    return ans

# %%
train_uid_df = pd.read_csv('../data/train/train_uid_df.csv', header = 0)
tmp = train_uid_df
train_uid_df_2 = do(tmp)
# Out:
# d:\program files (x86)\python\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-8cc094c6a81f> in <module>()
#       1 train_uid_df = pd.read_csv('../data/train/train_uid_df.csv', header = 0)
#       2 tmp = train_uid_df
# ----> 3 train_uid_df_2 = do(tmp)
#
# <ipython-input-5-52fa6e391aea> in do(dataset)
#       1 def do(dataset):
#       2     ans = dataset
# ----> 3     for index, row in dataset.iterrows():
#       4         tmp = row['uid']
#       5         ans.loc[index]['uid'] = tmp
#
# d:\program files (x86)\python\lib\site-packages\pandas\core\frame.pyc in iterrows(self)
#     746         klass = self._constructor_sliced
#     747         for k, v in zip(self.index, self.values):
# --> 748             s = klass(v, index=columns, name=k)
#     749             yield k, s
#     750
#
# d:\program files (x86)\python\lib\site-packages\pandas\core\series.pyc in __init__(self, data, index, dtype, name, copy, fastpath)
#     262             else:
#     263                 data = _sanitize_array(data, index, dtype, copy,
# --> 264                                        raise_cast_failure=True)
#     265
#     266                 data = SingleBlockManager(data, index, fastpath=True)
#
# d:\program files (x86)\python\lib\site-packages\pandas\core\series.pyc in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3193             subarr = _sanitize_index(data, index, copy=True)
#    3194         else:
# -> 3195             subarr = _try_cast(data, True)
#    3196
#    3197         if copy:
#
# d:\program files (x86)\python\lib\site-packages\pandas\core\series.pyc in _try_cast(arr, take_fast_path)
#    3159
#    3160         try:
# -> 3161             subarr = maybe_cast_to_datetime(arr, dtype)
#    3162             if not is_extension_type(subarr):
#    3163                 subarr = np.array(subarr, dtype=dtype, copy=copy)
#
# d:\program files (x86)\python\lib\site-packages\pandas\core\dtypes\cast.pyc in maybe_cast_to_datetime(value, dtype, errors)
#    1024     else:
#    1025
# -> 1026         is_array = isinstance(value, np.ndarray)
#    1027
#    1028         # catch a datetime/timedelta that is not of ns variety
#
# KeyboardInterrupt:

# %%
print(train_uid_df)
# Out:
#         uid  label
# 0     u0001      0
# 1     u0002      0
# 2     u0003      0
# 3     u0004      0
# 4     u0005      0
# 5     u0006      0
# 6     u0007      0
# 7     u0008      0
# 8     u0009      0
# 9     u0010      0
# 10    u0011      0
# 11    u0012      0
# 12    u0013      0
# 13    u0014      0
# 14    u0015      0
# 15    u0016      0
# 16    u0017      0
# 17    u0018      0
# 18    u0019      0
# 19    u0020      0
# 20    u0021      0
# 21    u0022      0
# 22    u0023      0
# 23    u0024      0
# 24    u0025      0
# 25    u0026      0
# 26    u0027      0
# 27    u0028      0
# 28    u0029      0
# 29    u0030      0
# ...     ...    ...
# 4969  u4970      1
# 4970  u4971      1
# 4971  u4972      1
# 4972  u4973      1
# 4973  u4974      1
# 4974  u4975      1
# 4975  u4976      1
# 4976  u4977      1
# 4977  u4978      1
# 4978  u4979      1
# 4979  u4980      1
# 4980  u4981      1
# 4981  u4982      1
# 4982  u4983      1
# 4983  u4984      1
# 4984  u4985      1
# 4985  u4986      1
# 4986  u4987      1
# 4987  u4988      1
# 4988  u4989      1
# 4989  u4990      1
# 4990  u4991      1
# 4991  u4992      1
# 4992  u4993      1
# 4993  u4994      1
# 4994  u4995      1
# 4995  u4996      1
# 4996  u4997      1
# 4997  u4998      1
# 4998  u4999      1
#
# [4999 rows x 2 columns]

# %%
train_voice_df_2 = do(train_voice_df)
train_sms_df_2 = do(train_sms_df)
train_wa_df_2 = do(train_wa_df)
